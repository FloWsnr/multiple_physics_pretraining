# %%
from .well_dataset import PhysicsDataset
from pathlib import Path

data_dir = Path(
    "/home/flwi01/coding/well_datasets/turbulent_radiative_layer_2D/data/train"
)  # Replace with actual data directory

dataset = PhysicsDataset(
    data_dir=data_dir,
    use_normalization=True,
    dt_stride=[1,100],#[1,8],
    full_trajectory_mode=False,
    num_channels=4,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from .well_dataset import PhysicsDataset
#       2 from pathlib import Path
#       4 data_dir = Path(
#       5     "/home/flwi01/coding/well_datasets/turbulent_radiative_layer_2D/data/train"
#       6 )  # Replace with actual data directory
#
# ImportError: attempted relative import with no known parent package

# %%
data = dataset[50]
print(data)
