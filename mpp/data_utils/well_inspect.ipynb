# %%
from mpp.data_utils.well_dataset import PhysicsDataset
from pathlib import Path

data_dir = Path(
    "/home/flwi01/coding/well_datasets/turbulent_radiative_layer_2D/data/train"
)  # Replace with actual data directory

dataset = PhysicsDataset(
    data_dir=data_dir,
    use_normalization=True,
    dt_stride=[1,8],#[1,8],
    full_trajectory_mode=False,
    num_channels=4,
)

# %%
x, y, labels, bcs = dataset[50]
print(x.shape, y.shape, labels, bcs)
# Out:
# torch.Size([16, 4, 128, 384]) torch.Size([1, 4, 128, 384]) tensor([0, 1, 2, 3]) tensor([2., 1.])
